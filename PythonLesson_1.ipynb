# %% [markdown]
# <a href="https://colab.research.google.com/github/melikeekara/weatherApp/blob/main/PythonLesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTHON PROGRAMMING LANGUAGE
#
# *   Variables and Variable Types
# *   Data Structures
# *   Conditions
# *   Loops
# *   Functions

# %%
x=5
type(x)
# Out:
# int

# %%
y=3.14
type(y)
# Out:
# float

# %%
lesson="CENG342"
type(lesson)
# Out:
# str

# %%
var=True
type(var)
# Out:
# bool

# %% [markdown]
# ![resim_2023-03-19_214943340.png](data:image/png;base64,...)

# %%
x=5
y=2
print(x+y)
# Out:
# 7

# %%
print(x-y)
# Out:
# 3

# %%
print(x*y)
# Out:
# 10

# %%
print(x/y)
# Out:
# 2.5

# %%
print(x//y)
# Out:
# 2

# %%
print(x**y)
# Out:
# 25

# %%
print(x%y)
# Out:
# 1

# %% [markdown]
# title function

# %%
name="melike kara"
print(name.title())
# Out:
# Melike Kara

# %% [markdown]
# upper() and lower() function

# %%
print(name.upper())
# Out:
# MELIKE KARA

# %%
print(name.lower())
# Out:
# melike kara

# %% [markdown]
# ![resim_2023-03-19_215141935.png](data:image/png;base64,...)

# %%
x=5
y=2

# %%
x<y
# Out:
# False

# %%
x>y
# Out:
# True

# %%
x!=y
# Out:
# True

# %% [markdown]
# # LOGICAL OPERATOR
#
#
# 1.   Logical operator are used to combine conditional statements.
# 2.   givest a Boolean result (True/False)
#
# ![resim_2023-03-19_215350342.png](data:image/png;base64,...))

# %%
x==y
# Out:
# False

# %%
x<=y
# Out:
# False

# %%
x>=y
# Out:
# True

# %%
x=5
y=2

# %%
y<6 and x<10
# Out:
# True

# %%
x<6 and x<10
# Out:
# True

# %%
y<6 or x<10
# Out:
# True

# %%
not(y<6 and x<10)
# Out:
# False
